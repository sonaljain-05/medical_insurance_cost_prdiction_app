# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import VotingRegressor
import warnings
warnings.filterwarnings("ignore")
from sklearn.ensemble import StackingRegressor
import pickle
! pip install openpyxl
from sklearn.model_selection import GridSearchCV

# %%
df=pd.read_excel("E:/data science/medical prediction/Medical Insurance.xlsm")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]>

# %%
print("shape ",df.shape)
print("nan_value  ",df.isnull().sum().sum())
print("duplicate_values"  ,df.duplicated().sum())
print("size ",df.size)
# Out:
# shape  (1338, 7)
# nan_value   0
# duplicate_values 1
# size  9366

# %%
df.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
df.columns = (
    df.columns
    .str.strip()                              
    .str.lower()                             
    .str.replace(r'\s+', ' ', regex=True)     
    .str.replace(' ', '_')                    
)

# %%
num_cols = ['age', 'bmi', 'children']
for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

cat_cols = ['sex', 'smoker', 'region']
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
dummies = pd.get_dummies(df[['sex', 'smoker', 'region']], drop_first=True)
df = pd.concat(
    [df.drop(['sex', 'smoker', 'region'], axis=1), dummies],
    axis=1
)

# %%
plt.figure(figsize=(5,3))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.corr(numeric_only=True).sum()
# Out:
# age                 1.402841
# bmi                 1.498317
# children            1.171716
# charges             2.400758
# sex_male            1.177932
# smoker_yes          1.844449
# region_northwest    0.133303
# region_southeast    0.702384
# region_southwest    0.274291
# dtype: float64

# %%
print(df.corr()['charges'].sort_values(ascending=False))
# Out:
# charges             1.000000
# smoker_yes          0.787251
# age                 0.299008
# bmi                 0.198341
# region_southeast    0.073982
# children            0.067998
# sex_male            0.057292
# region_northwest   -0.039905
# region_southwest   -0.043210
# Name: charges, dtype: float64

# %%
skewness = df.skew(numeric_only=True).sort_values(ascending=False)
print (skewness)
# Out:
# charges             1.515880
# smoker_yes          1.464766
# region_northwest    1.200409
# region_southwest    1.200409
# region_southeast    1.025621
# children            0.938380
# bmi                 0.284047
# age                 0.055673
# sex_male           -0.020951
# dtype: float64

# %%
skewed_columns=['age', 'bmi', 'children','charges']
for i in skewed_columns:
   df[i]=np.log1p(df[i])
df[skewed_columns].skew().sort_values(ascending=False)
# Out:
# children    0.264083
# charges    -0.089817
# bmi        -0.238240
# age        -0.361068
# dtype: float64

# %%
plt.figure(figsize=(6, 3))
sns.histplot(df['charges'].dropna(), kde=True,color="red")
plt.title('Distribution of Life Expectancy')
plt.xlabel('Life_Expectancy')
plt.ylabel('Frequency')
plt.show()

# %%
df.plot (kind='box',figsize=(6,3),color='green')
plt.xticks(rotation=90)
plt.show()

# %%
for col in df.select_dtypes(include=np.number).columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df[col] = np.where(df[col] < lower, lower, df[col])
    df[col] = np.where(df[col] > upper, upper, df[col])

# %%
x=df.drop('charges',axis=1)
y=df['charges']
x_train,x_test,y_train,y_test=train_test_split(x,y ,train_size=0.7,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((936, 8), (402, 8), (936,), (402,))

# %%
df.head()
# Out:
#         age       bmi  children   charges  sex_male  smoker_yes  \
# 0  2.995732  3.363842  0.000000  9.734236     False        True
# 1  2.944439  3.548755  0.693147  7.453882      True       False
# 2  3.367296  3.526361  1.386294  8.400763      True       False
# 3  3.526361  3.165686  0.000000  9.998137      True       False
# 4  3.496508  3.397189  0.000000  8.260455      True       False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False
# 3              True             False             False
# 4              True             False             False

# %%
scaler=StandardScaler()
x_train_sc=scaler.fit_transform(x_train)
x_test_sc = scaler.transform(x_test)
x_train=pd.DataFrame(x_train_sc,columns=x_train.columns,index=x_train.index)
x_test=pd.DataFrame(x_test_sc,columns=x_test.columns,index=x_test.index)

x_train.head(2)
# Out:
#           age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 332  1.315145  0.195470   -1.0482 -1.025978   -0.512989          1.757082
# 355  0.589377 -0.413527   -1.0482  0.974679   -0.512989         -0.569125
#
#      region_southeast  region_southwest
# 332         -0.593802         -0.557606
# 355         -0.593802          1.793381

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

def evaluate_model_performance(model, x_train, x_test, y_train, y_test):

    model.fit(x_train, y_train)

    train_pred = model.predict(x_train)
    test_pred = model.predict(x_test)

    train_r2 = r2_score(y_train, train_pred)
    test_r2 = r2_score(y_test, test_pred)

    n_train, p = x_train.shape
    n_test = x_test.shape[0]

    train_adj_r2 = 1 - ((1 - train_r2) * (n_train - 1)) / (n_train - p - 1)
    test_adj_r2 = 1 - ((1 - test_r2) * (n_test - 1)) / (n_test - p - 1)

    print(f"\n{model.__class__.__name__}")

    print("Train R2       :", round(train_r2, 3))
    print("Test R2        :", round(test_r2, 3))

    print("Train Adj R2   :", round(train_adj_r2, 3))
    print("Test Adj R2    :", round(test_adj_r2, 3))

    return model

# %%
evaluate_model_performance(
    model=LinearRegression(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# LinearRegression
# Train R2       : 0.762
# Test R2        : 0.784
# Train Adj R2   : 0.76
# Test Adj R2    : 0.78
# LinearRegression()

# %%
evaluate_model_performance(
    model=Lasso(alpha=0.1),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# Lasso
# Train R2       : 0.716
# Test R2        : 0.738
# Train Adj R2   : 0.714
# Test Adj R2    : 0.733
# Lasso(alpha=0.1)

# %%
evaluate_model_performance(
    model=Ridge(alpha=0.1),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# Ridge
# Train R2       : 0.762
# Test R2        : 0.784
# Train Adj R2   : 0.76
# Test Adj R2    : 0.78
# Ridge(alpha=0.1)

# %%
evaluate_model_performance(
    model=ElasticNet(alpha=0.1,l1_ratio=0.5),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# ElasticNet
# Train R2       : 0.738
# Test R2        : 0.76
# Train Adj R2   : 0.736
# Test Adj R2    : 0.755
# ElasticNet(alpha=0.1)

# %%
evaluate_model_performance(
    model=DecisionTreeRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# DecisionTreeRegressor
# Train R2       : 1.0
# Test R2        : 0.683
# Train Adj R2   : 1.0
# Test Adj R2    : 0.677
# DecisionTreeRegressor()

# %%
evaluate_model_performance(
    model=RandomForestRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# RandomForestRegressor
# Train R2       : 0.973
# Test R2        : 0.817
# Train Adj R2   : 0.973
# Test Adj R2    : 0.814
# RandomForestRegressor()

# %%
evaluate_model_performance(
    model=GradientBoostingRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# GradientBoostingRegressor
# Train R2       : 0.887
# Test R2        : 0.837
# Train Adj R2   : 0.886
# Test Adj R2    : 0.834
# GradientBoostingRegressor()

# %%
evaluate_model_performance(
    model=LGBMRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 325
# [LightGBM] [Info] Number of data points in the train set: 936, number of used features: 8
# [LightGBM] [Info] Start training from score 9.109175
#
# LGBMRegressor
# Train R2       : 0.935
# Test R2        : 0.818
# Train Adj R2   : 0.935
# Test Adj R2    : 0.814
# LGBMRegressor()

# %%
evaluate_model_performance(
    model=XGBRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# XGBRegressor
# Train R2       : 0.997
# Test R2        : 0.78
# Train Adj R2   : 0.997
# Test Adj R2    : 0.776
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
evaluate_model_performance(
    model=CatBoostRegressor(verbose= False),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# CatBoostRegressor
# Train R2       : 0.954
# Test R2        : 0.813
# Train Adj R2   : 0.954
# Test Adj R2    : 0.809
# CatBoostRegressor(loss_function='RMSE', verbose=False)

# %%
evaluate_model_performance(
    model=SVR(kernel='rbf'),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# SVR
# Train R2       : 0.844
# Test R2        : 0.842
# Train Adj R2   : 0.842
# Test Adj R2    : 0.839
# SVR()

# %%
evaluate_model_performance(
    model=KNeighborsRegressor(),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# KNeighborsRegressor
# Train R2       : 0.86
# Test R2        : 0.774
# Train Adj R2   : 0.859
# Test Adj R2    : 0.769
# KNeighborsRegressor()

# %%
model1 = LinearRegression()
model2 = RandomForestRegressor (n_estimators=100, random_state=42)
model3 = KNeighborsRegressor()



voting_regressor  =VotingRegressor(estimators=[('Ir', model1), ('rf', model2), ('knn', model3)])

evaluate_model_performance(
    model=voting_regressor,
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# VotingRegressor
# Train R2       : 0.904
# Test R2        : 0.825
# Train Adj R2   : 0.903
# Test Adj R2    : 0.822
# VotingRegressor(estimators=[('Ir', LinearRegression()),
#                             ('rf', RandomForestRegressor(random_state=42)),
#                             ('knn', KNeighborsRegressor())])

# %%
base_models =[
       ('dt',DecisionTreeRegressor(max_depth=5,random_state=42)),
        ('rf',RandomForestRegressor(n_estimators=50,random_state=42))
]

meta_model = KNeighborsRegressor()
stacking_regressor  =StackingRegressor(
    estimators=base_models,
    final_estimator=meta_model,
    n_jobs=-1
)




evaluate_model_performance(
    model=stacking_regressor,
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# StackingRegressor
# Train R2       : 0.857
# Test R2        : 0.785
# Train Adj R2   : 0.856
# Test Adj R2    : 0.781
# StackingRegressor(estimators=[('dt',
#                                DecisionTreeRegressor(max_depth=5,
#                                                      random_state=42)),
#                               ('rf',
#                                RandomForestRegressor(n_estimators=50,
#                                                      random_state=42))],
#                   final_estimator=KNeighborsRegressor(), n_jobs=-1)

# %%
models = [
    ("Linear Regression", LinearRegression()), ("Ridge", Ridge()), ("Lasso", Lasso()), 
    ("ElasticNet", ElasticNet()), ("Decision Tree", DecisionTreeRegressor()), 
    ("Random Forest", RandomForestRegressor()), ("AdaBoost", AdaBoostRegressor()), 
    ("Gradient Boost", GradientBoostingRegressor()), ("LGBM", LGBMRegressor()), 
    ("XGBoost", XGBRegressor()), ("CatBoost", CatBoostRegressor(verbose=0)), 
    ("SVM", SVR()), ("KNN", KNeighborsRegressor()), ("Bagging Regressor", BaggingRegressor())
]





from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
import pandas as pd

# Evaluation Function
def eval_data(y_true, y_pred, n_features):
    r2 = r2_score(y_true, y_pred)

    n = len(y_true)
    adj_r2 = 1 - ((1 - r2) * (n - 1)) / (n - n_features - 1)

    rmse = np.sqrt(mean_squared_error(y_true, y_pred))

    return r2, adj_r2, rmse


# Number of features
n_features = x_train.shape[1]

results = []

for name, m in models:
    try:
        m.fit(x_train, y_train)

        train_pred = m.predict(x_train)
        test_pred = m.predict(x_test)

        r2_tr, adj_tr, rmse_tr = eval_data(
            y_train, train_pred, n_features
        )

        r2_ts, adj_ts, rmse_ts = eval_data(
            y_test, test_pred, n_features
        )

        results.append({
            "Algorithms": name,
            "Train R2": r2_tr,
            "Test R2": r2_ts,
            "Train Adj R2": adj_tr,
            "Test Adj R2": adj_ts,
            "Train RMSE": rmse_tr,
            "Test RMSE": rmse_ts
        })

    except Exception as e:
        print(f"{name} skipped: {e}")

df_model = pd.DataFrame(results)

display(df_model.sort_values("Test R2", ascending=False))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 325
# [LightGBM] [Info] Number of data points in the train set: 936, number of used features: 8
# [LightGBM] [Info] Start training from score 9.109175
#            Algorithms  Train R2   Test R2  Train Adj R2  Test Adj R2  \
# 11                SVM  0.843596  0.841820      0.842247     0.838600
# 7      Gradient Boost  0.887341  0.837104      0.886369     0.833788
# 8                LGBM  0.935384  0.817771      0.934826     0.814061
# 5       Random Forest  0.973379  0.817627      0.973149     0.813914
# 10           CatBoost  0.954355  0.812970      0.953961     0.809163
# 13  Bagging Regressor  0.962134  0.792118      0.961807     0.787886
# 0   Linear Regression  0.762402  0.784392      0.760352     0.780003
# ...

# %%
ax = df_model.plot(
    x="Algorithms",
    y=["Train R2", "Test R2"], 
    kind="bar",  
    figsize=(18,6), 
    color=["#FFC0CB", "#FF69B4"],  
    width=0.8
)

plt.title("Performance Visualization", fontsize=20, fontweight="bold", pad=15) 
plt.xlabel("Scores", fontsize=20)
plt.ylabel("Algorithms", fontsize=20)

plt.xticks(rotation=90, ha='right', fontsize=20) 
for container in ax.containers:
    ax.bar_label(container, fmt='%.0f', label_type='edge', fontsize=15, padding=3)

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
catboost_regressor = CatBoostRegressor(
    random_state=42,
    verbose=0
)

param_grid = {
    'iterations': [1,50, 500],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8, 10],
    'l2_leaf_reg': [1, 3, 5, 7]
}

grid_search = GridSearchCV(
    estimator=catboost_regressor,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=3,
    verbose=2,
    n_jobs=-1
)

grid_search.fit(x_train, y_train)

print("Best parameters:", grid_search.best_params_)

best_model = grid_search.best_estimator_

y_pred = best_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Test MSE: {mse:.2f}")
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# Best parameters: {'depth': 4, 'iterations': 500, 'l2_leaf_reg': 1, 'learning_rate': 0.01}
# Test MSE: 0.13

# %%
best_model = grid_search.best_estimator_

# %%
evaluate_model_performance(
    model=CatBoostRegressor(
            depth= 4, 
            iterations= 500, 
            l2_leaf_reg= 1, 
            learning_rate= 0.01,               
            verbose=0               
),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# CatBoostRegressor
# Train R2       : 0.85
# Test R2        : 0.843
# Train Adj R2   : 0.848
# Test Adj R2    : 0.84
# CatBoostRegressor(depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01, loss_function='RMSE', verbose=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor
import numpy as np

catboost_regressor = CatBoostRegressor(random_state=42, verbose=0)

param_grid = {
    'iterations': [50, 500],
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [4, 6, 8, 10],
    'l2_leaf_reg': [1, 3, 5, 7]
}

grid_search = GridSearchCV(
    estimator=catboost_regressor,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=3,
    n_jobs=-1,
    verbose=2
)

grid_search.fit(x_train, y_train)

best_model = grid_search.best_estimator_

y_pred = best_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("Best Parameters:", grid_search.best_params_)
print("Test MSE:", round(mse, 4))
print("Test RMSE:", round(rmse, 4))
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# Best Parameters: {'depth': 4, 'iterations': 500, 'l2_leaf_reg': 1, 'learning_rate': 0.01}
# Test MSE: 0.1318
# Test RMSE: 0.3631

# %%
catboost_regressor = CatBoostRegressor(
    depth=4,                   
    iterations=500,
    l2_leaf_reg=1,
    learning_rate=0.01,
    verbose=0
)
evaluate_model_performance(
    model=catboost_regressor,
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# CatBoostRegressor
# Train R2       : 0.85
# Test R2        : 0.843
# Train Adj R2   : 0.848
# Test Adj R2    : 0.84
# CatBoostRegressor(depth=4, iterations=500, l2_leaf_reg=1, learning_rate=0.01, loss_function='RMSE', verbose=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {
    'max_depth': [3, 4, 5, 6, 8, 10],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 5, 10]
}

grid = GridSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_grid,
    cv=5,
    scoring='r2'
)

grid.fit(x_train, y_train)

print(grid.best_params_)
# Out:
# {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
evaluate_model_performance(
    model=DecisionTreeRegressor(
        max_depth= 4, 
        min_samples_leaf= 1, 
        min_samples_split= 2, 
        random_state=42


),
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test
)
# Out:
# DecisionTreeRegressor
# Train R2       : 0.833
# Test R2        : 0.814
# Train Adj R2   : 0.832
# Test Adj R2    : 0.81
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
                           # FINAL VERDICT

 #Tuned CatBoost is slightly better than SVM.

# Reasons:

#Test R² is marginally higher (0.843 vs 0.842).
#Adjusted R² is also slightly higher.
#Train-Test gap is still very small, so overfitting is not a concern.
#Since CatBoost has been optimized using GridSearchCV, it represents your best-tuned model.

#The difference is tiny (0.001), so in practical terms both models perform almost identically.
#  But if you have to choose one final model for the report, I would select:

#Final Model: CatBoost Regressor (Tuned with GridSearchCV)

#Because:

#Highest Test R²
#Strong generalization
#Hyperparameter optimization performed
#More defensible choice in a project/report

#So for your Final Verdict & Performance Evaluation, I'd write it around the tuned CatBoost model rather than SVM.

# %%
grid_search.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 grid_search.fit(x_train, y_train)
#
# NameError: name 'grid_search' is not defined

# %%
best_model = grid_search.best_estimator_

y_pred = best_model.predict(x_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print("Best Parameters:", grid_search.best_params_)
print("Test MSE:", round(mse, 4))
print("Test RMSE:", round(rmse, 4))
# Out:
# Best Parameters: {'depth': 4, 'iterations': 500, 'l2_leaf_reg': 1, 'learning_rate': 0.01}
# Test MSE: 0.1318
# Test RMSE: 0.3631

# %%
x = pd.get_dummies(x)
columns = x.columns
joblib.dump(columns, "columns.pkl")
# Out:
# ['columns.pkl']

# %%
import joblib

best_model = grid_search.best_estimator_

joblib.dump(best_model, "best_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(list(x.columns), "columns.pkl")
# Out:
# ['columns.pkl']
